# %%
import pandas as pd

# %%
file = "Resources/cities.csv"
file_pd = pd.read_csv(file)

#sort by=['Date']

file_pd.set_index('City_ID', inplace=True)
file_pd
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 tiksi  71.69  128.87    -28.43        69           0
# 1               rikitea -23.12 -134.97     78.44        79           0
# 2          kruisfontein -34.00   24.73     69.94        81          11
# 3                narsaq  60.92  -46.05     15.80        66          75
# 4          san patricio  19.22 -104.70     77.85        66          39
# ...                 ...    ...     ...       ...       ...         ...
# 560              gunjur  13.20  -16.73     95.50        16          92
# 561      imeni morozova  59.98   31.04     30.99        66         100
# 562              lompoc  34.64 -120.46     64.00        87           1
# 563            olafsvik  64.89  -23.71     34.11        96         100
# 564        constitucion -35.33  -72.42     71.83        42           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.10      RU  1579974245
# ...

# %%
html=file_pd.to_html(classes = ["table-bordered", "table-striped", "table-hover"])
print(html)
# Out:
# <table border="1" class="dataframe table-bordered table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#     <tr>
#       <th>City_ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>tiksi</td>
#       <td>71.69</td>
#       <td>128.87</td>
#       <td>-28.43</td>
#       <td>69</td>
#       <td>0</td>
#       <td>5.10</td>
#       <td>RU</td>
#       <td>1579974245</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>rikitea</td>
#       <td>-23.12</td>
#       <td>-134.97</td>
#       <td>78.44</td>
# ...
